# %% [markdown]
# - 실행 할것

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt 
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');
# Out:
# <img src="data:image/png;base64,..." width="640">
